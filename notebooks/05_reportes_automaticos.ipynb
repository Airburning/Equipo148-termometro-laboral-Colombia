# %% [markdown]
# # 05 - Reportes automáticos
#
# Lee los artefactos que ya generó el pipeline (`data/04_model_output/metrics.json`, `report_data.json`) y las figuras de `reports/figures/`, para armar un resumen rápido sin tener que abrir `reports/reporte_final.html`.

# %%
import sys
from pathlib import Path

REPO_ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
sys.path.insert(0, str(REPO_ROOT / "src"))

import pandas as pd
import matplotlib.pyplot as plt

from config import INTERMEDIATE_DIR, PRIMARY_DIR, MODEL_OUTPUT_DIR

pd.set_option("display.max_columns", 50)

# %%
import json

metrics = json.load(open(MODEL_OUTPUT_DIR / "metrics.json"))
pd.DataFrame(metrics["results"]).T

# %%
print("Mejor modelo:", metrics["best_model"])
print("n_train:", metrics["n_train"], " n_test:", metrics["n_test"])

# %% [markdown]
# ## Proyección del próximo semestre por región

# %%
pd.read_csv(MODEL_OUTPUT_DIR / "forecast_next_period.csv")

# %% [markdown]
# ## Figuras generadas por `src/generate_figures.py`

# %%
from IPython.display import Image, display

for f in sorted((REPO_ROOT / "reports" / "figures").glob("*.png")):
    print(f.name)
    display(Image(filename=str(f)))

# %% [markdown]
# Para regenerar estos artefactos desde cero: `python pipelines/pipeline_ml.py` (corre las 6 extracciones, el modelo, el forecast y las figuras/dashboard en un solo comando).
